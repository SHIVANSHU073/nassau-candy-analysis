# %% [markdown]
# # 05 predictive modeling
#
# Train Linear Regression, Random Forest and Gradient Boosting with chronological validation.
#
# **Guardrail:** recorded lead times are anomalously long and alternative-factory effects are not historically identified.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / 'src'))
print(ROOT)
