# %% [markdown]
# # 08 optimization
#
# Rank investigation priorities using transparent speed, financial-exposure and risk weights.
#
# **Guardrail:** recorded lead times are anomalously long and alternative-factory effects are not historically identified.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / 'src'))
print(ROOT)
